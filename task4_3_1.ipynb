# %%
import matplotlib.pyplot as plt
import numpy as np

arr = np.random.sample(10)
median = np.median(arr)
avg = np.average(arr)

print(arr)
print(median)
print(avg)

data = np.arange(0.0, 1, 0.1)
plt.scatter(arr, data)
# Out:
# [0.91767228 0.15435909 0.71032177 0.42233016 0.31604814 0.78778374
#  0.66195454 0.30148002 0.18255205 0.67095176]
# 0.5421423489986155
# 0.5125453558445277
