# %%
from numpy import sqrt
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(1, 15, 0.5)
y = sqrt(1 + np.e ** sqrt(x) + np.cos(x * x)) / abs(1 - np.sin(x) ** 3) + np.log(np.abs(2 * x))

plt.grid()
plt.plot(x, y, c = 'g')
