# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(1, 10, 1)
y = np.abs(np.cos(x * np.e ** (np.cos(x) + np.log(x + 1))))
plt.grid()
plt.plot(x, y, c = 'g')
plt.fill_between(x, y)

area = np.trapz(y)
print(area)
# Out:
# 5.281433013197265
