# %%
import matplotlib.pyplot as plt

months = ['янв', 'фев', 'мар', 'апр', 'май', 'июн', 'июл', 'авг', 'сен', 'окт', 'ноя', 'дек']

apple = [130.61, 120.02, 121.08, 130.31, 123.52, 135.99, 144.83, 150.76, 140.71, 148.97, 164.38, 176.84]

microsoft = [228.54, 228.95, 232.83, 249.03, 246.56, 268.14, 282.00, 298.80, 279.58, 328.87, 327.84, 334.14]

google = [1824.50, 2021.30, 2072.70, 2355.00, 2365.60, 2441.20, 2703.00, 2901.40, 2678.50, 2962.50, 2866.20, 2900.30]

plt.plot(months, apple, c='r', label='apple')
plt.plot(months, microsoft, c='b', label='microsoft')
plt.plot(months, google, c='g', label='google')

plt.xlabel("Months")
plt.ylabel("Stock prices")
plt.legend()

plt.show()
